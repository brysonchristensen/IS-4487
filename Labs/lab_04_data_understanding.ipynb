# %% [markdown]
# > ### Note on Labs and Assigments:
# >
# > 🔧 Look for the **wrench emoji** 🔧 — it highlights where you're expected to take action!
# >
# > These sections are graded and are not optional.
# >

# %% [markdown]
# # IS 4487 Lab 4: Data Understanding
#
# ## Outline
#
# - Load and preview a real-world dataset
# - Inspect structure and identify missing or unusual data
# - Perform basic grouped summaries
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/lab_04_data_understanding.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# If you have any questions about Colab, you can read more here:
# https://research.google.com/colaboratory/faq.html

# %% [markdown]
# ## Dataset Overview
#
# **Dataset:** `rent.csv`
# Source: [TidyTuesday – 2022-07-05](https://github.com/rfordatascience/tidytuesday/blob/main/data/2022/2022-07-05/rent.csv)
#
# | Variable       | Type       | Description |
# |----------------|------------|-------------|
# | `post_id`      | Categorical| Unique listing ID |
# | `date`         | Numeric    | Listing date (numeric format) |
# | `year`         | Integer    | Year of listing |
# | `nhood`        | Categorical| Neighborhood |
# | `city`         | Categorical| City |
# | `county`       | Categorical| County |
# | `price`        | Numeric    | Listing price (USD) |
# | `beds`         | Numeric    | Number of bedrooms |
# | `baths`        | Numeric    | Number of bathrooms |
# | `sqft`         | Numeric    | Square footage |
# | `room_in_apt`  | Binary     |  Indicates whether the rental listing is for an entire apartment (0) or a single room within an apartment (1). |
# | `address`      | Categorical| Street address |
# | `lat`          | Numeric    | Latitude |
# | `lon`          | Numeric    | Longitude |
# | `title`        | Text       | Listing title |
# | `descr`        | Text       | Listing description |
# | `details`      | Text       | Additional details |

# %% [markdown]
# ## Part 1: Importing the Data
#
# ### Instructions:
# - Import the `pandas` library.
# - Import data from the rent.csv into a dataframe from the tidytuesday link.
# - Use `.info()` and `.head()` to inspect the structure and preview the data.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2022/2022-07-05/rent.csv'
df = pd.read_csv(url)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200796 entries, 0 to 200795
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   post_id      200796 non-null  object
#  1   date         200796 non-null  int64
#  2   year         200796 non-null  int64
#  3   nhood        200796 non-null  object
#  4   city         200796 non-null  object
#  5   county       199402 non-null  object
#  6   price        200796 non-null  int64
#  7   beds         194188 non-null  float64
#  8   baths        42675 non-null   float64
#  9   sqft         64679 non-null   float64
#  10  room_in_apt  200796 non-null  int64
#  11  address      3908 non-null    object
#  12  lat          7651 non-null    float64
#  13  lon          4312 non-null    float64
#  14  title        198279 non-null  object
#  15  descr        3254 non-null    object
#  16  details      8016 non-null    object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 26.0+ MB

# %%
df.head()
# Out:
#           post_id      date  year    nhood     city   county  price  beds  \
# 0  pre2013_134138  20050111  2005  alameda  alameda  alameda   1250   2.0
# 1  pre2013_135669  20050126  2005  alameda  alameda  alameda   1295   2.0
# 2  pre2013_127127  20041017  2004  alameda  alameda  alameda   1100   2.0
# 3   pre2013_68671  20120601  2012  alameda  alameda  alameda   1425   1.0
# 4  pre2013_127580  20041021  2004  alameda  alameda  alameda    890   1.0
#
#    baths   sqft  room_in_apt address  lat  lon  \
# 0    2.0    NaN            0     NaN  NaN  NaN
# 1    NaN    NaN            0     NaN  NaN  NaN
# 2    NaN    NaN            0     NaN  NaN  NaN
# 3    NaN  735.0            0     NaN  NaN  NaN
# 4    NaN    NaN            0     NaN  NaN  NaN
#
#                                                title descr details
# 0  $1250 / 2br - 2BR/2BA   1145 ALAMEDA DE LAS PU...   NaN     NaN
# 1  $1295 / 2br - Walk the Beach! 1 FREE MONTH + $...   NaN     NaN
# 2                              $1100 / 2br - cottage   NaN     NaN
# 3  $1425 / 1br - 735ft² - BEST LOCATION SOUTHSHOR...   NaN     NaN
# 4  $890 / 1br - Classy "Painted Lady" VICTORIAN -...   NaN     NaN

# %% [markdown]
# ### 🔧 Try It Yourself – Part 1
#
# 1. Add one line of code to print the number of rows and columns.

# %%
print(df.shape)
# Out:
# (200796, 17)

# %% [markdown]
# ## Part 2: Inspecting, Cleaning & Removing Outliers
#
# ### Instructions:
# - Identify missing values.
# - Check data types are correct(e.g., dates, numeric columns).
# - Check for outliers key numeric variables like `price`, `sqft`, `beds`, or `baths`.
#
# ### Think about:
# - Are there missing values?
# - Do the data types look appropriate?
# - Do any numeric variables contain extreme or unusual values?

# %%
# Check for missing values
df.isnull().sum()
# Out:
# post_id             0
# date                0
# year                0
# nhood               0
# city                0
# county           1394
# price               0
# beds             6608
# baths          158121
# sqft           136117
# room_in_apt         0
# address        196888
# lat            193145
# lon            196484
# title            2517
# descr          197542
# details        192780
# dtype: int64

# %% [markdown]
# Yes, there are missing values in several columns, including county, beds, baths, sqft, address, lat, lon, title, descr, and details. The columns with the most missing values are address, lat, lon, descr, and details.

# %%
# Basic summary statistics
df[['price', 'beds', 'baths', 'sqft']].describe()
# Out:
#                price           beds         baths           sqft
# count  200796.000000  194188.000000  42675.000000   64679.000000
# mean     2135.362746       1.889025      1.679086    1201.827688
# std      1427.747903       1.079138      0.690509    5000.217864
# min       220.000000       0.000000      1.000000      80.000000
# 25%      1295.000000       1.000000      1.000000     750.000000
# 50%      1800.000000       2.000000      2.000000    1000.000000
# 75%      2505.000000       3.000000      2.000000    1360.000000
# max     40000.000000      12.000000      8.000000  900000.000000

# %%
# Check data types
df.dtypes
# Out:
# post_id         object
# date             int64
# year             int64
# nhood           object
# city            object
# county          object
# price            int64
# beds           float64
# baths          float64
# sqft           float64
# room_in_apt      int64
# address         object
# lat            float64
# lon            float64
# title           object
# descr           object
# details         object
# dtype: object

# %% [markdown]
# The data types generally look appropriate. post_id, nhood, city, county, address, title, descr, and details are objects (strings), which makes sense. date and year are integers, which is fine, although date might be more useful as a datetime object for time-series analysis. price, beds, baths, sqft, lat, and lon are numeric (int64 or float64), which is also appropriate. room_in_apt is an integer, representing a binary variable, which is correct.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot of price
sns.boxplot(x=df['price'])
plt.title("Boxplot of Rental Price")
plt.show()

# %% [markdown]
# Based on the descriptive statistics and the boxplot of price, it appears that there are some extreme or unusual values in the price column. The maximum price is significantly higher than the 75th percentile, and the boxplot shows several outliers.

# %%
# Remove price outliers (1st–99th percentile)
q_low = df['price'].quantile(0.01)
q_high = df['price'].quantile(0.99)
df = df[(df['price'] >= q_low) & (df['price'] <= q_high)]

# %% [markdown]
# ### 🔧 Try It Yourself – Part 2
#
# 1. Use `.describe()` and a boxplot to check for outliers in **square footage (`sqft`)**.
#
# 2. What patterns or issues do you see with square footage values? Is there anything unusual?

# %%
# Check for outliers in sqft using describe()
print(df['sqft'].describe())

# Boxplot of sqft
sns.boxplot(x=df['sqft'])
plt.title("Boxplot of Square Footage")
plt.show()
# Out:
# count     61379.000000
# mean       1146.720556
# std        5117.038910
# min          80.000000
# 25%         750.000000
# 50%         995.000000
# 75%        1300.000000
# max      900000.000000
# Name: sqft, dtype: float64

# %% [markdown]
# 🔧 Add comment here: Based on the .describe() output and the boxplot for sqft, there are clearly extreme outliers. The maximum value (900,000 sqft) is unrealistically large for a rental property and significantly skews the mean and standard deviation. This suggests data entry errors or incorrect units for some listings. These outliers should likely be investigated or removed before further analysis.

# %% [markdown]
# ## Part 3: Basic Exploration
#
# Use `groupby` and `value_counts` to summarize trends across neighborhoods and cities.

# %%
# Average price by neighborhood
df.groupby('nhood')['price'].mean().sort_values(ascending=False).head(10)
# Out:
# nhood
# inverness                     4950.000000
# SOMA / south beach            3209.197432
# financial district            3069.550580
# tiburon / belvedere           3024.980568
# candlestick point             3011.316239
# west portal / forest hills    2883.768750
# saratoga                      2871.351171
# NOPA                          2754.571970
# pacific heights               2703.609323
# cazadero                      2700.000000
# Name: price, dtype: float64

# %%
# Top cities by count
df['city'].value_counts().head(10)
# Out:
# city
# san francisco    51482
# san jose         13224
# oakland           8653
# santa rosa        5946
# santa cruz        5256
# san mateo         5015
# sunnyvale         4410
# mountain view     4297
# santa clara       4053
# berkeley          3879
# Name: count, dtype: int64

# %% [markdown]
# ### 🔧 Try It Yourself – Part 3
#
# Explore the data by performing both of the following:
#
# 1. Group the listings by `year` and calculate the average price for each year.
# 2. Use `.value_counts()` on the `room_in_apt` column to see how common room rentals are.
#
# 3. Add a short comment or markdown cell describing any trends or insights you found.

# %%
# Average price by year
print("Average price by year:")
print(df.groupby('year')['price'].mean())

# Count of room_in_apt values
print("\nValue counts for room_in_apt:")
print(df['room_in_apt'].value_counts())
# Out:
# Average price by year:
# year
# 2000    1703.235294
# 2001    1999.352609
# 2002    1694.127273
# 2003    1576.854279
# 2004    1639.385765
# 2005    1524.032792
# 2006    1736.588042
# 2007    1963.325296
# 2008    1929.328811
# 2009    1837.882945
# 2010    1782.329511
# 2011    1967.688403
# 2012    2004.986763
# 2013    2400.771833
# 2014    2525.631387
# 2015    2702.137142
# 2016    2663.890741
# 2017    2782.028521
# 2018    2721.748823
# Name: price, dtype: float64
#
# Value counts for room_in_apt:
# room_in_apt
# 0    189125
# 1       228
# Name: count, dtype: int64

# %% [markdown]
# 🔧 Add comment here: Square Footage (sqft): There are significant outliers in the sqft column, with a maximum value that appears unrealistic for a rental property. This suggests potential data entry errors or incorrect units, and these outliers should be addressed.
# Average Price by Year: The average rental price has generally increased over the years, although there are some fluctuations.
# Room Rentals (room_in_apt): The value_counts() for room_in_apt shows that listings for entire apartments (0) are significantly more common than listings for single rooms within an apartment (1).

# %% [markdown]
# ## Export Your Notebook to Submit in Canvas
# - Use the instructions from Lab 1

# %%
# !jupyter nbconvert --to html "lab_04_ChristensenBryson.ipynb"
# Out:
# [NbConvertApp] Converting notebook lab_04_ChristensenBryson.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 356779 bytes to lab_04_ChristensenBryson.html
